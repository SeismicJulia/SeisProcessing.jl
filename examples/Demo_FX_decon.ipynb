# %%
using PyPlot, SeisPlot, SeisMain, SeisProcessing

# FX Deconvolution for SNR enhancement

# %%
d = SeisLinearEvents(dt=0.004,nx1=120,dx1=.4,
                     p1  = [-0.001,0.0003,-0.003],p2=[0.0,0.0,0.0],p3=[0.0,0.0,0.0],
                     p4=[0.0,0.0,0.0],amp=[1.0,-1.0,1.0],
                     tau = [0.6,0.7,1.4])
dn = SeisAddNoise(d,.5,L=5)

Param = Dict(:dt=>0.004,:mu=>0.00,:filter_length=>4,:fmax=>100) 

df = SeisFXDecon(dn,Param);


figure(4,figsize=(6,6))
clf()
SeisPlotTX(hcat(d[:,1:3:end],dn[:,1:3:end],df[:,1:3:end]),style="wiggles",fignum=4)
gcf()
# Out:
# 1.4899217385628925 + 0.0im
# 1.4655249505029773 + 0.0im
# 1.6050599277649997 + 0.0im
# 1.5670366703314713 + 0.0im
# 1.6956697891730748 + 0.0im
# 1.7161871777795532 + 0.0im
# 1.607609642407956 + 0.0im
# 1.5488658265203714 + 0.0im
# 1.6467202799781544 + 0.0im
# 1.5982354446481688 + 0.0im
# 1.584067576999036 + 0.0im
# 1.6918287560411196 + 0.0im
# 1.4424341982693063 + 0.0im
# 1.409635546945217 + 0.0im
# 1.4587675353767302 + 0.0im
# 1.419492706368455 + 0.0im
# 1.881360936386965 + 0.0im
# 1.8520591528163277 + 0.0im
# 1.629940233705274 + 0.0im
# 1.628301361561737 + 0.0im
# 1.484219908884443 + 0.0im
# 1.4588582761248612 + 0.0im
# 1.8164622542200737 + 0.0im
# 1.7867234232427531 + 0.0im
# 1.3666669421237225 + 0.0im
# 1.4138908616709032 + 0.0im
# 1.506380292623608 + 0.0im
# 1.4669165211917996 + 0.0im
# 1.4927178663439173 + 0.0im
# 1.3917486012404678 + 0.0im
# 1.3673460553362733 + 0.0im
# 1.4119890121171792 + 0.0im
# 1.4067050893945745 + 0.0im
# 1.3874773923379633 + 0.0im
# 1.7419832503567045 + 0.0im
# 1.7018181559617964 + 0.0im
# 1.8027959707353123 + 0.0im
# 1.7729843575642366 + 0.0im
# 1.9535484210718639 + 0.0im
# 1.9578426136505158 + 0.0im
# 1.858056152525907 + 0.0im
# 1.7555473557060282 + 0.0im
# 1.7891638447566323 + 0.0im
# 1.7184186064761422 + 0.0im
# 1.9546586898194744 + 0.0im
# 1.9491611680102798 + 0.0im
# 2.1520522935704953 + 0.0im
# 2.0685507064343187 + 0.0im
# 1.973475240253665 + 0.0im
# 1.9415517179442483 + 0.0im
# 1.9886911908700373 + 0.0im
# 2.0788617761933468 + 0.0im
# 2.1411309998486505 + 0.0im
# 2.2043626116549286 + 0.0im
# 2.121314232242308 + 0.0im
# 2.1428256319391012 + 0.0im
# 1.7908255622312845 + 0.0im
# 1.8834955915607063 + 0.0im
# 2.045607396367676 + 0.0im
# 2.1086900065045144 + 0.0im
# 2.2532658402115984 + 0.0im
# 2.1465538567913107 + 0.0im
# 1.8021639078928646 + 0.0im
# 1.8547211091253473 + 0.0im
# 1.828666600285193 + 0.0im
# 1.7980100179233132 + 0.0im
# 2.1742911534810103 + 0.0im
# 2.295960368326685 + 0.0im
# 2.2263894203613153 + 0.0im
# 2.097719082455687 + 0.0im
# 2.012431331762891 + 0.0im
# 2.0681822502170935 + 0.0im
# 2.3824106637228066 + 0.0im
# 2.375166907797432 + 0.0im
# 1.9640631818743748 + 0.0im
# 1.9529718827379197 + 0.0im
# 2.0950601640396824 + 0.0im
# 2.1222175925708155 + 0.0im
# 2.141232644885134 + 0.0im
# 2.131665671655304 + 0.0im
# 2.2515568211500105 + 0.0im
# 2.2764676256734675 + 0.0im
# 2.3997263218065656 + 0.0im
# 2.4088392310939097 + 0.0im
# 2.0834550813486423 + 0.0im
# 2.024841202281495 + 0.0im
# 2.1621279493017265 + 0.0im
# 2.2610658606487273 + 0.0im
# 1.9659598264370017 + 0.0im
# 1.965515289642733 + 0.0im
# 2.3333307699841326 + 0.0im
# 2.274820993817567 + 0.0im
# 2.07906929747927 + 0.0im
# 2.0175135273857565 + 0.0im
# 2.0058559541516927 + 0.0im
# 2.086612374193407 + 0.0im
# 1.8958857421369373 + 0.0im
# 1.8899635031184012 + 0.0im
# 1.869463171077762 + 0.0im
# 1.953192102341 + 0.0im
# 1.6773329817187423 + 0.0im
# 1.7992079156036496 + 0.0im
# 1.6561712626423237 + 0.0im
# 1.7354083611546836 + 0.0im
# 1.4747988778497854 + 0.0im
# 1.4596626781413522 + 0.0im
# 1.677017041093617 + 0.0im
# 1.6775173526861755 + 0.0im
# 1.6386307494539103 + 0.0im
# 1.5569604987772538 + 0.0im
# 1.4966981684416796 + 0.0im
# 1.5281793878347185 + 0.0im
# 1.5990508806442623 + 0.0im
# 1.512913938116601 + 0.0im
# 1.7633921679964843 + 0.0im
# 1.7061277899765224 + 0.0im
# 1.4451569872230192 + 0.0im
# 1.4811443305458243 + 0.0im
# 1.5351181549205788 + 0.0im
# 1.4730485740092063 + 0.0im
# 1.347098348949371 + 0.0im
# 1.3826749881747176 + 0.0im
# 1.294076034804948 + 0.0im
# 1.2731286385040415 + 0.0im
# 1.0841004061017891 + 0.0im
# 1.1989783966807581 + 0.0im
# 1.1041913879756513 + 0.0im
# 1.1258701488129865 + 0.0im
# 1.3198978508575383 + 0.0im
# 1.315071928269805 + 0.0im
# 1.0512044353693277 + 0.0im
# 1.0532878764829734 + 0.0im
# 1.109174561706164 + 0.0im
# 1.1756368452791401 + 0.0im
# 1.2557528022951634 + 0.0im
# 1.174491540682563 + 0.0im
# 1.010713616104065 + 0.0im
# 0.9535058865215224 + 0.0im
# 0.9202884551768351 + 0.0im
# 0.8989700658295174 + 0.0im
# 0.8741301490680345 + 0.0im
# 0.9713862713971788 + 0.0im
# 1.0304723617748663 + 0.0im
# 1.0666068140558584 + 0.0im
# 0.9971377402652452 + 0.0im
# 1.0014637965702728 + 0.0im
# 0.9281045742839499 + 0.0im
# 0.9145228794218871 + 0.0im
# 0.9404255143995455 + 0.0im
# 0.9142510991799359 + 0.0im
# 0.7985308669271951 + 0.0im
# 0.780986173181399 + 0.0im
# 0.7440134421036523 + 0.0im
# 0.7350168885458204 + 0.0im
# 0.7644226183604033 + 0.0im
# 0.7504256732718553 + 0.0im
# 0.8096032095137509 + 0.0im
# 0.8628750958680009 + 0.0im
# 0.7276656917189609 + 0.0im
# 0.7091147227232517 + 0.0im
# 0.7742380477633116 + 0.0im
# 0.7879316524265189 + 0.0im
# 0.5819857216707932 + 0.0im
# 0.5954105026056429 + 0.0im
# 0.6996437329994977 + 0.0im
# 0.6944068907144098 + 0.0im
# 0.8227765404015763 + 0.0im
# 0.8321725833991875 + 0.0im
# 0.6620585989905924 + 0.0im
# 0.63883209683766 + 0.0im
# 0.6522697718281701 + 0.0im
# 0.6012247021908471 + 0.0im
# 0.5885615709079248 + 0.0im
# 0.5797934319420577 + 0.0im
# 0.5219318375957355 + 0.0im
# 0.5421641977815215 + 0.0im
# 0.6069405164062508 + 0.0im
# 0.6397658989381836 + 0.0im
# 0.5428832288135887 + 0.0im
# 0.5369510711461177 + 0.0im
# 0.570210444110482 + 0.0im
# 0.5494972485287806 + 0.0im
# 0.6421510677569688 + 0.0im
# 0.6161750779044071 + 0.0im
# 0.5502666367784993 + 0.0im
# 0.5521011867447029 + 0.0im
# 0.5670283493294727 + 0.0im
# 0.5505200231805858 + 0.0im
# 0.423288075578074 + 0.0im
# 0.42173814333566134 + 0.0im
# 0.49467830398354395 + 0.0im
# 0.521147577043973 + 0.0im
# 0.5112581302986061 + 0.0im
# 0.5304806606029875 + 0.0im
# 0.47091177153946767 + 0.0im
# 0.47960218223531575 + 0.0im
# 0.4379160337483888 + 0.0im
# 0.4500205327270861 + 0.0im
# 0.49158226531046856 + 0.0im
# 0.4821511348162385 + 0.0im
# 0.38118718048846845 + 0.0im
# 0.3954084322365125 + 0.0im
# 0.45473032900255395 + 0.0im
# 0.454921371826667 + 0.0im
# 0.35958480081977995 + 0.0im
# 0.3680315421833357 + 0.0im
# 0.40139807804498095 + 0.0im
# 0.4177192254514388 + 0.0im
# 0.4185135993905802 + 0.0im
# 0.4456075681225713 + 0.0im
# 0.4156971162234286 + 0.0im
# 0.404596015021944 + 0.0im
# 0.3973653337947936 + 0.0im
# 0.3802771908724356 + 0.0im
# 0.3322097502572878 + 0.0im
# 0.3406257761789115 + 0.0im
# 0.32491419250081216 + 0.0im
# 0.3197666407346899 + 0.0im
# 0.36347345523236124 + 0.0im
# 0.36252641091242055 + 0.0im
# 0.3858765392935255 + 0.0im
# 0.37384252742507856 + 0.0im
# 0.31600979237870824 + 0.0im
# 0.3336269931693654 + 0.0im
# 0.3091486571599344 + 0.0im
# 0.3018372780341417 + 0.0im
# 0.33656146282999894 + 0.0im
# 0.3366732321824405 + 0.0im
# 0.293037186022309 + 0.0im
# 0.29182065942472846 + 0.0im
# 0.3111265615827847 + 0.0im
# 0.2958452115588534 + 0.0im
# 0.2411846060051613 + 0.0im
# 0.2492570539513334 + 0.0im
# 0.2996843592539462 + 0.0im
# 0.2731401878745047 + 0.0im
# 0.29788392881746273 + 0.0im
# 0.30128699826428074 + 0.0im
# 0.3137738117374743 + 0.0im
# 0.31713447244493 + 0.0im
# 0.30567868666120446 + 0.0im
# 0.30140093890578545 + 0.0im
# 0.20309743132524424 + 0.0im
# 0.21650499899544062 + 0.0im
# 0.27028908619097936 + 0.0im
# 0.2898328237298593 + 0.0im
# 0.2031644831184159 + 0.0im
# 0.2067369126660682 + 0.0im
# 0.21344370748658353 + 0.0im
# 0.21799233149378874 + 0.0im
# 0.20175628005436064 + 0.0im
# 0.2181233475773597 + 0.0im
# 0.20406115816437848 + 0.0im
# 0.2041374259375915 + 0.0im
# 0.23479536263295395 + 0.0im
# 0.2308641812806526 + 0.0im
# 0.2179649811135144 + 0.0im
# 0.22387546850182147 + 0.0im
# 0.19792749988540098 + 0.0im
# 0.2020240909241392 + 0.0im
# 0.17706910265211362 + 0.0im
# 0.17066333803033032 + 0.0im
# 0.1864058722028098 + 0.0im
# 0.18769974847459633 + 0.0im
# 0.18916983383490038 + 0.0im
# 0.19311541052745618 + 0.0im
# 0.1573632928164476 + 0.0im
# 0.1692080852541674 + 0.0im
# 0.15549795868451052 + 0.0im
# 0.15345168679580537 + 0.0im
# 0.1642940158784275 + 0.0im
# 0.16526794162413225 + 0.0im
# 0.1438022235908931 + 0.0im
# 0.13723314844477713 + 0.0im
# 0.139532694288762 + 0.0im
# 0.13546318169485713
#  + 0.0im
# 0.15452563254646734 + 0.0im
# 0.1574267759181114 + 0.0im
# 0.15071773018863519 + 0.0im
# 0.1433101796586721 + 0.0im
# 0.10650863657229268 + 0.0im
# 0.11034269505195791 + 0.0im
# 0.1311652062686289 + 0.0im
# 0.12795220639578817 + 0.0im
# 0.12058200928945695 + 0.0im
# 0.1121018969163147 + 0.0im
# 0.10031838075917786 + 0.0im
# 0.10449714527919102 + 0.0im
# 0.10629234522666418 + 0.0im
# 0.10487746266293647 + 0.0im
# 0.09925442071176853 + 0.0im
# 0.10256047763717702 + 0.0im
# 0.10574814146270185 + 0.0im
# 0.10845656700799053 + 0.0im
# 0.09867067755414738 + 0.0im
# 0.10215820322845669 + 0.0im
# 0.09723665086772529 + 0.0im
# 0.09761954287358071 + 0.0im
# 0.09947869490709207 + 0.0im
# 0.10861720323694003 + 0.0im
# 0.08395176988540833 + 0.0im
# 0.0880008094588975 + 0.0im
# 0.0800003797687787 + 0.0im
# 0.07887430059104686 + 0.0im
# 0.08054151609636195 + 0.0im
# 0.0798808492665031 + 0.0im
# 0.08012221892590793 + 0.0im
# 0.08082779141891354 + 0.0im
# 0.06542240272303265 + 0.0im
# 0.06530605972558567 + 0.0im
# 0.06878225511346783 + 0.0im
# 0.06524256069569503 + 0.0im
# 0.06047785320221096 + 0.0im
# 0.0626645009648808 + 0.0im
# 0.06866272170887239 + 0.0im
# 0.06823118989079684 + 0.0im
# 0.06472828014452282 + 0.0im
# 0.06502898767193992 + 0.0im
# 0.06584425645626717 + 0.0im
# 0.06483215850510483 + 0.0im
# 0.061643056407206506 + 0.0im
# 0.06066416376926713 + 0.0im
# 0.06429497607559734 + 0.0im
# 0.0687782263112297 + 0.0im
# 0.0581226282369657 + 0.0im
# 0.05912156985587444 + 0.0im
# 0.05831729860928472 + 0.0im
# 0.05979554346721771 + 0.0im
# 0.04546610078717257 + 0.0im
# 0.04399198226398773 + 0.0im
# 0.04267332941957519 + 0.0im
# 0.042553994340514795 + 0.0im
# 0.0466364157355444 + 0.0im
# 0.04651542958866277 + 0.0im
# 0.05297293303422629 + 0.0im
# 0.05387041067702929 + 0.0im
# 0.044569440256512015 + 0.0im
# 0.04494153966196469 + 0.0im
# 0.03916462756928351 + 0.0im
# 0.03971461663959856 + 0.0im
# 0.03932084033728653 + 0.0im
# 0.040127069384560475 + 0.0im
# 0.03545703830808236 + 0.0im
# 0.03678076329730109 + 0.0im
# 0.038667470002081664 + 0.0im
# 0.040734626697342825 + 0.0im
# 0.03809054584493207 + 0.0im
# 0.03632346044604612 + 0.0im
# 0.031802889814234264 + 0.0im
# 0.031037387799689536 + 0.0im
# 0.028340192844011382 + 0.0im
# 0.02792824903359088 + 0.0im
# 0.03497603246023818 + 0.0im
# 0.03277515326300663 + 0.0im
# 0.02795806377187001 + 0.0im
# 0.028190408064300176 + 0.0im
# 0.02290626361623689 + 0.0im
# 0.02273973081019293 + 0.0im
# 0.028538376134339734 + 0.0im
# 0.029699745807775905 + 0.0im
# 0.02442883162604318 + 0.0im
# 0.024665505630873663 + 0.0im
# 0.019523844283844575 + 0.0im
# 0.019268827682529993 + 0.0im
# 0.02041152436552274 + 0.0im
# 0.01998631897178543 + 0.0im
# 0.020769367207068175 + 0.0im
# 0.021066246271686753 + 0.0im
# 0.0215754529874138 + 0.0im
# 0.021888793617247812 + 0.0im
# 0.019140522284467068 + 0.0im
# 0.020001200496050208 + 0.0im
# 0.01932893221791561 + 0.0im
# 0.01985741635749717 + 0.0im
# 0.018517624022814178 + 0.0im
# 0.019502886855877005 + 0.0im
# 0.016561916334271683 + 0.0im
# 0.016712893563693616 + 0.0im
# 0.014921936656223196 + 0.0im
# 0.015635342938652298 + 0.0im
# 0.017927223245406944 + 0.0im
# 0.017908895596711282 + 0.0im
# 0.0137816407637166 + 0.0im
# 0.012868745151976873 + 0.0im
# 0.014494562269131792 + 0.0im
# 0.015445242455429855 + 0.0im
# 0.014982698980918559 + 0.0im
# 0.015113402318490675 + 0.0im
# 0.011856061368396387 + 0.0im
# 0.011523870764579678 + 0.0im
# 0.013308424847897328 + 0.0im
# 0.0125092297268196 + 0.0im
# 0.013154924103317362 + 0.0im
# 0.01259435461785005 + 0.0im
# 0.012503088283366206 + 0.0im
# 0.01228149299107794 + 0.0im
# 0.010873244277189276 + 0.0im
# 0.011721485870888598 + 0.0im
# 0.010200855052883581 + 0.0im
# 0.010200322287977924 + 0.0im
# 0.010734957033181043 + 0.0im
# 0.010478467344763548 + 0.0im
# 0.009788294902894755 + 0.0im
# 0.009472707291328436 + 0.0im
# 0.00727077104692353 + 0.0im
# 0.007647463010828781 + 0.0im
# 0.007886438401540635 + 0.0im
# 0.00776200273826267 + 0.0im
# 0.008622399954358094 + 0.0im
# 0.008377677539772057 + 0.0im
# 0.006746320171846782 + 0.0im
# 0.006664140189760331 + 0.0im
# 0.007586292664500099 + 0.0im
# 0.007902251115339265 + 0.0im
# 0.007645453047675461 + 0.0im
# 0.00695831911731573 + 0.0im
# 0.0068397422372636855 + 0.0im
# 0.006918888260251055 + 0.0im
# 0.006179596356032106 + 0.0im
# 0.006564028782508729 + 0.0im
# 0.0060662766561686565 + 0.0im
# 0.0063660604477523645 + 0.0im
# 0.005794824838188466 + 0.0im
# 0.0055921646680839624 + 0.0im
# 0.005673744966594059 + 0.0im
# 0.005838967790781845 + 0.0im
# 0.006003883861134505 + 0.0im
# 0.006641882713361505 + 0.0im
# 0.005204551067180334 + 0.0im
# 0.0053312868362639645 + 0.0im
# 0.005153602909328084 + 0.0im
# 0.005392078089776956 + 0.0im
# 0.004907043503512354 + 0.0im
# 0.004824565861617059 + 0.0im
# 0.0043673025620960485 + 0.0im
# 0.0042618388849043195 + 0.0im
# 0.005505347411503417 + 0.0im
# 0.005437601136971192 + 0.0im
# 0.004468376679747887 + 0.0im
# 0.004564034458914458 + 0.0im
# 0.0034142356166757563 + 0.0im
# 0.003511300338232728 + 0.0im
# 0.003758991467678166 + 0.0im
# 0.003986681427150054 + 0.0im
# 0.003833996180713885 + 0.0im
# 0.00379280015399106 + 0.0im
# 0.004496956545961009 + 0.0im
# 0.00464952359376409 + 0.0im
# 0.003930392496532305 + 0.0im
# 0.0038751807889712254 + 0.0im
# 0.0040106748190146405 + 0.0im
# 0.0041477861735040615 + 0.0im
# 0.003803602686494179 + 0.0im
# 0.003928248947506301 + 0.0im
# 0.0035287681786641983 + 0.0im
# 0.003535280568144487 + 0.0im
# 0.0033868430607628132 + 0.0im
# 0.003445608514873534 + 0.0im
# 0.003012870957804931 + 0.0im
# 0.0027856198527081892 + 0.0im
# 0.0028747204433452957 + 0.0im
# 0.0029416654541254126 + 0.0im
# 0.0031738983314971254 + 0.0im
# 0.0031817032933713174 + 0.0im
# 0.00264325251960709 + 0.0im
# 0.0025266172333317854 + 0.0im
# 0.0024466916350842013 + 0.0im
# 0.0023931612346393466 + 0.0im
# 0.002481130990076377 + 0.0im
# 0.0025324022474031275 + 0.0im
# 0.002772298351023449 + 0.0im
# 0.002694313657993525 + 0.0im
# 0.0026650390328309915 + 0.0im
# 0.0025340362054450684 + 0.0im
# 0.0025931564739439883 + 0.0im
# 0.0024791416865211345 + 0.0im
# 0.0024019584874650514 + 0.0im
# 0.0025005182996624942 + 0.0im
# 0.0024587819392621678 + 0.0im
# 0.0024744100715878123 + 0.0im
# 0.002632840348883324 + 0.0im
# 0.002585984664943351 + 0.0im
# 0.002402787411271554 + 0.0im
# 0.0024480841748774646 + 0.0im
# 0.00247645936136216 + 0.0im
# 0.0025584785218948263 + 0.0im
# 0.002000863311459522 + 0.0im
# 0.0021987054028202876 + 0.0im
# 0.0022195066201582177 + 0.0im
# 0.0021962324498112605 + 0.0im
# 0.002525754471259435 + 0.0im
# 0.002536207346876078 + 0.0im
# 0.002310600149651968 + 0.0im
# 0.002435074075533632 + 0.0im
# 0.002069187389334726 + 0.0im
# 0.0020886843851783622 + 0.0im
# 0.002062076476766322 + 0.0im
# 0.00204529347370624 + 0.0im
# 0.002144933344389337 + 0.0im
# 0.0022206938862449816 + 0.0im
# Figure(PyObject <Figure size 600x600 with 1 Axes>)

# %%
MeasureSNR(d,dn,db=true)
# Out:
# 1.928654933106574e-15
